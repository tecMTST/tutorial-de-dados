# %%
import pandas as pd

# %%
df = pd.read_csv('/content/receitas_candidatos.csv', encoding='latin-1', sep=';')

# %%
df.columns
# Out:
# Index(['Ano de eleição', 'Cargo', 'Esfera', 'Esfera partidária',
#        'Espécie receita', 'Fonte de receita', 'Município', 'Nome candidato',
#        'Nome doador', 'Origem da receita', 'Partido', 'Região',
#        'Situação de candidatura', 'Situação de totalização', 'UF',
#        'Valor de receita', 'Data de carga'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10237 entries, 0 to 10236
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ano de eleição           10237 non-null  int64
#  1   Cargo                    10237 non-null  object
#  2   Esfera                   10237 non-null  object
#  3   Esfera partidária        10237 non-null  object
#  4   Espécie receita          10237 non-null  object
#  5   Fonte de receita         10237 non-null  object
#  6   Município                10237 non-null  object
#  7   Nome candidato           10237 non-null  object
#  8   Nome doador              10237 non-null  object
#  9   Origem da receita        10237 non-null  object
#  10  Partido                  10237 non-null  object
#  11  Região                   10237 non-null  object
#  12  Situação de candidatura  10237 non-null  object
#  13  Situação de totalização  10237 non-null  object
# ...

# %%
df['Valor de receita'] = df['Valor de receita'].str.replace(',', '.').astype(float)

# %%
df[df['Nome candidato']=='JOICE CRISTINA HASSELMANN']
# Out:
#       Ano de eleição             Cargo              Esfera Esfera partidária  \
# 449             2022  Deputado Federal  Estadual/Distrital     Não se aplica
# 6373            2022  Deputado Federal  Estadual/Distrital     Não se aplica
#
#                Espécie receita Fonte de receita Município  \
# 449                   Estimado   FUNDO ESPECIAL         -
# 6373  Transferência eletrônica   FUNDO ESPECIAL         -
#
#                  Nome candidato                              Nome doador  \
# 449   JOICE CRISTINA HASSELMANN  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA
# 6373  JOICE CRISTINA HASSELMANN  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA
#
#                  Origem da receita Partido   Região Situação de candidatura  \
# 449   Recursos de partido político    PSDB  SUDESTE                    Apto
# 6373  Recursos de partido político    PSDB  SUDESTE                    Apto
#
#      Situação de totalização  UF  Valor de receita        Data de carga
# ...

# %%
df_candidato = df.groupby('Nome candidato')['Valor de receita'].sum().reset_index()

# %%
df_candidatos2 = df_candidato.merge(df.loc[:,['Nome candidato', 'Situação de totalização', 'Partido']], left_on='Nome candidato', right_on='Nome candidato', how='left').drop_duplicates()

# %% [markdown]
# Adicionar uma explicação sobre como funciona a contagem de eleição e o que é Eleito QP, Eleito por média, Suplente e Não eleito

# %%
df_candidatos2.sort_values(by='Valor de receita', ascending=False).head(25)
# Out:
#                                   Nome candidato  Valor de receita  \
# 1131                ARNALDO CALIL PEREIRA JARDIM        3789999.99
# 8357            RENATA HELLMEISTER DE ABREU MELO        3313917.40
# 5530                LUIZ PAULO TEIXEIRA FERREIRA        3281293.48
# 4237                   JOICE CRISTINA HASSELMANN        3221072.53
# 7990             PAULO ALEXANDRE PEREIRA BARBOSA        3188141.60
# 4698                                  JOSÉ SERRA        3175000.00
# 4240                    JONAS DONIZETTE FERREIRA        3147286.96
# 410                        ALEX SPINELLI MANENTE        3107760.02
# 9762                            VANDERLEI MACRIS        3096833.36
# 6364                      MARCOS ANTONIO PEREIRA        3093528.55
# 8863                    ROSANA DE OLIVEIRA VALLE        3043728.88
# 63                      ADILSON BARROSO OLIVEIRA        3003431.42
# 3372           FREDERICO AUGUSTO ARANTES MACHADO        2996590.90
# ...
